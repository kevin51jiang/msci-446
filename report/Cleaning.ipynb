# %%
import pandas as pd

# %%
df = pd.read_json('rNormalized.json')

df
# Out:
#       steamId                               itadPlain  itad.position  \
# 0      524220                            nierautomata              1
# 1      413150                           stardewvalley              2
# 2      435150  divinityoriginalsiniidefinitiveedition              3
# 3         620                                portalii              4
# 4      292030                      witcheriiiwildhunt              5
# ...       ...                                     ...            ...
# 2222   860890                             factorytown           2495
# 2223   270850              carmechanicsimulatorii0iiv           2496
# 2224    46450              grotesquetacticsevilheroes           2497
# 2225   572430                             partyhardii           2498
# 2226   585450                        shadowsawakening           2499
#
#       itad.rank                                         itad.sales  \
# 0             1  [{'shopId': '25', 'shopName': 'Gamesload', 'ti...
# ...
